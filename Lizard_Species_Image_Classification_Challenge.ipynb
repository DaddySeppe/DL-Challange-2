# %% [markdown]
# # Lizard Species Image Classification Challenge

# %% [markdown]
# ## Team Members
# - Team member 1: seppe
# - Team member 2:jonas
# - Team member 3:

# %% [markdown]
# ## Introduction
# This project is a Kaggle image classification challenge for our Artificial Intelligence course. The goal is to classify images into 7 different lizard species using deep learning with TensorFlow/Keras.
#
# This notebook will later include EDA, preprocessing, data augmentation, transfer learning, training, evaluation, a confusion matrix, and a Kaggle submission.

# %% [markdown]
# ## Project Requirements
# - Jupyter Notebook with markdown documentation
# - EDA on the dataset
# - TensorFlow/Keras model
# - Data augmentation
# - Transfer learning
# - Training and validation plots
# - Model evaluation with confusion matrix
# - Valid Kaggle submission
# - GenAI usage section

# %% [markdown]
# ## Imports

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

print("TensorFlow version:", tf.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 import os
# ----> 2 import numpy as np
#       3 import pandas as pd
#       4 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'numpy'

# %% [markdown]
# ## Dataset Paths
# The dataset paths are defined here. These paths may need to be changed depending on where the Kaggle data is stored.

# %%
train_dir = "train"
test_dir = "test"

if os.path.exists(train_dir):
    print("Train folder found")
else:
    print("Train folder not found, check the path")

if os.path.exists(test_dir):
    print("Test folder found")
else:
    print("Test folder not found, check the path")
